# %% [markdown]
# Practice Project - 1

# %%
# All Library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# pandas section

data = pd.read_csv("employee_data_ds_practice.csv")
print("Original Dataset:- \n",data.to_string())
print("First five column:- \n",data.head(5).to_string())
print("Find the number of rows and columns:- \n",data.shape)
print("Display all column names. \n", data.columns)
print("Check the data types. \n", data.dtypes)
print("Check for missing values. \n",data.isna().sum())
name_department_salary = data[['Name','Department','Salary']]
print("Display only Name, Department, and Salary. \n",name_department_salary)
emp_slry_45k = data[data['Salary']>45000]
print("Find employees whose salary is greater than 45000. \n", emp_slry_45k.to_string())
it_dept = data[data['Department']=='IT']
print("It Dept Emp:- \n", it_dept.to_string())
slry_HL = data.sort_values('Salary',ascending=False)
print("Highest to lowest Salary:- \n", slry_HL.to_string())

# numpy section

np_arr_slry = np.array(data["Salary"])
print("all employee salary in a array:-",np_arr_slry)
ave_slry = np.mean(np_arr_slry)
print("Average salary is:-",ave_slry)
max_slry = np.max(np_arr_slry)
print("Maximun Salary is :-",max_slry)
min_slry = np.min(np_arr_slry)
print("Minimun Salary is :-",min_slry)
slry_difference = max_slry - min_slry
print("salary difference between the highest-paid and lowest-paid employee:- ", slry_difference)
data['salary increase(10%)'] = np.array(data['Salary'] / 10)
data['Gross Salary'] = data['Salary'] + data['salary increase(10%)']
print(data.to_string())

for_mat = data.groupby('Department')['Salary'].mean()
print(for_mat)

# matplotlib section task - 1

plt.figure(figsize=(10,5))
plt.bar(for_mat.index, 
        for_mat.values,
        color='green',
        linewidth=2,
        alpha=0.8
)
plt.grid(color='black')
plt.title("Department wise Average Salary Visual")
plt.xlabel('Department')
plt.ylabel('Average Salary')
plt.show()

# task - 2

plt.scatter(data['Experience_Years'],data['Salary'],
            alpha=0.8,
            marker='o',
            color='orange'
)
plt.xlabel('Experience_Years')
plt.ylabel('Salary')
plt.title('Visualize Exp_year and salary using scatter')
plt.grid()
plt.show()

# task - 3

plt.hist(data['Salary'],
         alpha=0.5,
         bins=4
)
plt.title('Visualize Salary Using Histogram')
plt.grid()
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.show()
# Out:
# Original Dataset:-
#      Employee_ID    Name Department  Age  Salary  Experience_Years  Performance_Score  Projects_Completed
# 0           101   Rahul         IT   24   35000                 1                 78                   2
# 1           102   Priya         HR   29   42000                 4                 85                   5
# 2           103    Aman         IT   26   38000                 2                 82                   3
# 3           104   Sneha    Finance   32   55000                 7                 91                   8
# 4           105   Rohit         HR   28   45000                 5                 88                   6
# 5           106  Anjali         IT   25   40000                 2                 80                   3
# 6           107   Karan    Finance   35   60000                 9                 95                  10
# 7           108    Neha         IT   27   39000                 3                 84                   4
# 8           109  Vikram      Sales   31   48000                 6                 89                   7
# 9           110   Pooja         HR   30   46000                 5                 86                   6
# 10          111   Arjun      Sales   33   52000                 8                 92                   9
# 11          112    Riya    Finance   36   58000                10                 94                  11
# First five column:-
#     Employee_ID   Name Department  Age  Salary  Experience_Years  Performance_Score  Projects_Completed
# 0          101  Rahul         IT   24   35000                 1                 78                   2
# 1          102  Priya         HR   29   42000                 4                 85                   5
# 2          103   Aman         IT   26   38000                 2                 82                   3
# 3          104  Sneha    Finance   32   55000                 7                 91                   8
# 4          105  Rohit         HR   28   45000                 5                 88                   6
# Find the number of rows and columns:-
#  (12, 8)
# Display all column names.
#  Index(['Employee_ID', 'Name', 'Department', 'Age', 'Salary',
#        'Experience_Years', 'Performance_Score', 'Projects_Completed'],
#       dtype='object')
# Check the data types.
#  Employee_ID            int64
# Name                  object
# Department            object
# Age                    int64
# Salary                 int64
# Experience_Years       int64
# Performance_Score      int64
# Projects_Completed     int64
# dtype: object
# Check for missing values.
#  Employee_ID           0
# Name                  0
# Department            0
# Age                   0
# Salary                0
# Experience_Years      0
# Performance_Score     0
# Projects_Completed    0
# dtype: int64
# Display only Name, Department, and Salary.
#        Name Department  Salary
# 0    Rahul         IT   35000
# 1    Priya         HR   42000
# 2     Aman         IT   38000
# 3    Sneha    Finance   55000
# 4    Rohit         HR   45000
# 5   Anjali         IT   40000
# 6    Karan    Finance   60000
# 7     Neha         IT   39000
# 8   Vikram      Sales   48000
# 9    Pooja         HR   46000
# 10   Arjun      Sales   52000
# 11    Riya    Finance   58000
# Find employees whose salary is greater than 45000.
#      Employee_ID    Name Department  Age  Salary  Experience_Years  Performance_Score  Projects_Completed
# 3           104   Sneha    Finance   32   55000                 7                 91                   8
# 6           107   Karan    Finance   35   60000                 9                 95                  10
# 8           109  Vikram      Sales   31   48000                 6                 89                   7
# 9           110   Pooja         HR   30   46000                 5                 86                   6
# 10          111   Arjun      Sales   33   52000                 8                 92                   9
# 11          112    Riya    Finance   36   58000                10                 94                  11
# It Dept Emp:-
#     Employee_ID    Name Department  Age  Salary  Experience_Years  Performance_Score  Projects_Completed
# 0          101   Rahul         IT   24   35000                 1                 78                   2
# 2          103    Aman         IT   26   38000                 2                 82                   3
# 5          106  Anjali         IT   25   40000                 2                 80                   3
# 7          108    Neha         IT   27   39000                 3                 84                   4
# Highest to lowest Salary:-
#      Employee_ID    Name Department  Age  Salary  Experience_Years  Performance_Score  Projects_Completed
# 6           107   Karan    Finance   35   60000                 9                 95                  10
# 11          112    Riya    Finance   36   58000                10                 94                  11
# 3           104   Sneha    Finance   32   55000                 7                 91                   8
# 10          111   Arjun      Sales   33   52000                 8                 92                   9
# 8           109  Vikram      Sales   31   48000                 6                 89                   7
# 9           110   Pooja         HR   30   46000                 5                 86                   6
# 4           105   Rohit         HR   28   45000                 5                 88                   6
# 1           102   Priya         HR   29   42000                 4                 85                   5
# 5           106  Anjali         IT   25   40000                 2                 80                   3
# 7           108    Neha         IT   27   39000                 3                 84                   4
# 2           103    Aman         IT   26   38000                 2                 82                   3
# 0           101   Rahul         IT   24   35000                 1                 78                   2
# all employee salary in a array:- [35000 42000 38000 55000 45000 40000 60000 39000 48000 46000 52000 58000]
# Average salary is:- 46500.0
# Maximun Salary is :- 60000
# Minimun Salary is :- 35000
# salary difference between the highest-paid and lowest-paid employee:-  25000
#     Employee_ID    Name Department  Age  Salary  Experience_Years  Performance_Score  Projects_Completed  salary increase(10%)  Gross Salary
# 0           101   Rahul         IT   24   35000                 1                 78                   2                3500.0       38500.0
# 1           102   Priya         HR   29   42000                 4                 85                   5                4200.0       46200.0
# 2           103    Aman         IT   26   38000                 2                 82                   3                3800.0       41800.0
# 3           104   Sneha    Finance   32   55000                 7                 91                   8                5500.0       60500.0
# 4           105   Rohit         HR   28   45000                 5                 88                   6                4500.0       49500.0
# 5           106  Anjali         IT   25   40000                 2                 80                   3                4000.0       44000.0
# 6           107   Karan    Finance   35   60000                 9                 95                  10                6000.0       66000.0
# 7           108    Neha         IT   27   39000                 3                 84                   4                3900.0       42900.0
# 8           109  Vikram      Sales   31   48000                 6                 89                   7                4800.0       52800.0
# 9           110   Pooja         HR   30   46000                 5                 86                   6                4600.0       50600.0
# 10          111   Arjun      Sales   33   52000                 8                 92                   9                5200.0       57200.0
# 11          112    Riya    Finance   36   58000                10                 94                  11                5800.0       63800.0
# Department
# Finance    57666.666667
# HR         44333.333333
# IT         38000.000000
# Sales      50000.000000
# Name: Salary, dtype: float64
